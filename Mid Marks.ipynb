# %% [markdown]
# Name : V.JAHHNAVI Roll NO: 2211CS010583 Section: GROUP-3 Sem Id: G-3(48) DA CASE STUDY ON MIDMARKS DATASET

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("MIDMARKS.xlsx")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 711   NaN    ZETA  19    8   8   19  17   18
# 712   NaN    ZETA  12    1   7   10  20    8
# 713   NaN    ZETA  17    6  14   14  17   18
# 714   NaN    ZETA  12    1   6    7  15   12
# 715   NaN    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df.shape
# Out:
# (716, 8)

# %%
df.size
# Out:
# 5728

# %%
df.rename(columns={'M-II':'M2'},inplace=True)

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12   0  17    9  19   15
# 1     2.0   ALPHA  19  12  16   16  18    3
# 2     3.0   ALPHA  18  14  18   18  18   16
# 3     4.0   ALPHA  15   9  19   17  19   15
# 4     5.0   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 711   NaN    ZETA  19   8   8   19  17   18
# 712   NaN    ZETA  12   1   7   10  20    8
# 713   NaN    ZETA  17   6  14   14  17   18
# 714   NaN    ZETA  12   1   6    7  15   12
# 715   NaN    ZETA  19  14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df=df.replace("A","AB")

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12   0  17    9  19   15
# 1     2.0   ALPHA  19  12  16   16  18    3
# 2     3.0   ALPHA  18  14  18   18  18   16
# 3     4.0   ALPHA  15   9  19   17  19   15
# 4     5.0   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 711   NaN    ZETA  19   8   8   19  17   18
# 712   NaN    ZETA  12   1   7   10  20    8
# 713   NaN    ZETA  17   6  14   14  17   18
# 714   NaN    ZETA  12   1   6    7  15   12
# 715   NaN    ZETA  19  14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df=df.replace("AB",-1)
df=df.replace("MP",-2)

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE    FL  FIMS
# 0     1.0   ALPHA  12   0  17     9  19.0    15
# 1     2.0   ALPHA  19  12  16    16  18.0     3
# 2     3.0   ALPHA  18  14  18    18  18.0    16
# 3     4.0   ALPHA  15   9  19    17  19.0    15
# 4     5.0   ALPHA  18  17  19    19  20.0    18
# ..    ...     ...  ..  ..  ..   ...   ...   ...
# 711   NaN    ZETA  19   8   8    19  17.0    18
# 712   NaN    ZETA  12   1   7    10  20.0     8
# 713   NaN    ZETA  17   6  14    14  17.0    18
# 714   NaN    ZETA  12   1   6     7  15.0    12
# 715   NaN    ZETA  19  14  17    16  20.0    19
#
# [716 rows x 8 columns]

# %%
b = df.dropna()
b
# Out:
#       S.NO SECTION  DV  M2  PP  BEEE    FL  FIMS
# 0      1.0   ALPHA  12   0  17     9  19.0    15
# 1      2.0   ALPHA  19  12  16    16  18.0     3
# 2      3.0   ALPHA  18  14  18    18  18.0    16
# 3      4.0   ALPHA  15   9  19    17  19.0    15
# 4      5.0   ALPHA  18  17  19    19  20.0    18
# ..     ...     ...  ..  ..  ..   ...   ...   ...
# 595  596.0   SIGMA  20  20  20    20  20.0    20
# 596  597.0   SIGMA  20  20  20    19  19.0    18
# 597  598.0   SIGMA  20  20  17    17  19.0    18
# 598  599.0   SIGMA  14  12  11     9  18.0    17
# 599  600.0   SIGMA  20  19  20    18  18.0    19
#
# [599 rows x 8 columns]

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE    FL  FIMS
# 0       1   ALPHA  12   0  17     9  19.0    15
# 1       2   ALPHA  19  12  16    16  18.0     3
# 2       3   ALPHA  18  14  18    18  18.0    16
# 3       4   ALPHA  15   9  19    17  19.0    15
# 4       5   ALPHA  18  17  19    19  20.0    18
# ..    ...     ...  ..  ..  ..   ...   ...   ...
# 711   712    ZETA  19   8   8    19  17.0    18
# 712   713    ZETA  12   1   7    10  20.0     8
# 713   714    ZETA  17   6  14    14  17.0    18
# 714   715    ZETA  12   1   6     7  15.0    12
# 715   716    ZETA  19  14  17    16  20.0    19
#
# [716 rows x 8 columns]

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA')
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
print("Updated DataFrame with missing sections replaced by 'SIGMA':")
df
# Out:
# Updated DataFrame with missing sections replaced by 'SIGMA':
#      S.NO SECTION  DV  M2  PP  BEEE    FL  FIMS
# 0       1   ALPHA  12   0  17     9  19.0    15
# 1       2   ALPHA  19  12  16    16  18.0     3
# 2       3   ALPHA  18  14  18    18  18.0    16
# 3       4   ALPHA  15   9  19    17  19.0    15
# 4       5   ALPHA  18  17  19    19  20.0    18
# ..    ...     ...  ..  ..  ..   ...   ...   ...
# 711   712    ZETA  19   8   8    19  17.0    18
# 712   713    ZETA  12   1   7    10  20.0     8
# 713   714    ZETA  17   6  14    14  17.0    18
# 714   715    ZETA  12   1   6     7  15.0    12
# 715   716    ZETA  19  14  17    16  20.0    19
#
# [716 rows x 8 columns]

# %%
df=df.fillna(0)
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE    FL  FIMS
# 0       1   ALPHA  12   0  17     9  19.0    15
# 1       2   ALPHA  19  12  16    16  18.0     3
# 2       3   ALPHA  18  14  18    18  18.0    16
# 3       4   ALPHA  15   9  19    17  19.0    15
# 4       5   ALPHA  18  17  19    19  20.0    18
# ..    ...     ...  ..  ..  ..   ...   ...   ...
# 711   712    ZETA  19   8   8    19  17.0    18
# 712   713    ZETA  12   1   7    10  20.0     8
# 713   714    ZETA  17   6  14    14  17.0    18
# 714   715    ZETA  12   1   6     7  15.0    12
# 715   716    ZETA  19  14  17    16  20.0    19
#
# [716 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    int64
#  3   M2       716 non-null    int64
#  4   PP       716 non-null    int64
#  5   BEEE     716 non-null    int64
#  6   FL       716 non-null    float64
#  7   FIMS     716 non-null    int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 44.9+ KB

# %%
df['DV'] = pd.to_numeric(df['DV'], errors='coerce')
df['DV'] = df['DV'].fillna(0)
df['DV'] = df['DV'].astype(int)

# %%
df['M2'] = pd.to_numeric(df['M2'], errors='coerce')
df['M2'] = df['M2'].fillna(0)
df['M2'] = df['M2'].astype(int)

# %%
df['PP'] = pd.to_numeric(df['PP'], errors='coerce')
df['PP'] = df['PP'].fillna(0)
df['PP'] = df['PP'].astype(int)

# %%
df['BEEE'] = pd.to_numeric(df['BEEE'], errors='coerce')
df['BEEE'] = df['BEEE'].fillna(0)
df['BEEE'] = df['BEEE'].astype(int)

# %%
df['FL'] = pd.to_numeric(df['FL'], errors='coerce')
df['FL'] = df['FL'].fillna(0)
df['FL'] = df['FL'].astype(int)

# %%
df['FIMS'] = pd.to_numeric(df['FIMS'], errors='coerce')
df['FIMS'] = df['FIMS'].fillna(0)
df['FIMS'] = df['FIMS'].astype(int)

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS
# 0       1   ALPHA  12   0  17     9  19    15
# 1       2   ALPHA  19  12  16    16  18     3
# 2       3   ALPHA  18  14  18    18  18    16
# 3       4   ALPHA  15   9  19    17  19    15
# 4       5   ALPHA  18  17  19    19  20    18
# ..    ...     ...  ..  ..  ..   ...  ..   ...
# 711   712    ZETA  19   8   8    19  17    18
# 712   713    ZETA  12   1   7    10  20     8
# 713   714    ZETA  17   6  14    14  17    18
# 714   715    ZETA  12   1   6     7  15    12
# 715   716    ZETA  19  14  17    16  20    19
#
# [716 rows x 8 columns]

# %%
df['Total']=df['DV']+df['M2']+df['PP']+df['BEEE']+df['FL']+df['FIMS']
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total
# 0       1   ALPHA  12   0  17     9  19    15     72
# 1       2   ALPHA  19  12  16    16  18     3     84
# 2       3   ALPHA  18  14  18    18  18    16    102
# 3       4   ALPHA  15   9  19    17  19    15     94
# 4       5   ALPHA  18  17  19    19  20    18    111
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...
# 711   712    ZETA  19   8   8    19  17    18     89
# 712   713    ZETA  12   1   7    10  20     8     58
# 713   714    ZETA  17   6  14    14  17    18     86
# 714   715    ZETA  12   1   6     7  15    12     53
# 715   716    ZETA  19  14  17    16  20    19    105
#
# [716 rows x 9 columns]

# %%
df['Percentage']=round((df['Total']/120)*100,2)
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17
# 712   713    ZETA  12   1   7    10  20     8     58       48.33
# 713   714    ZETA  17   6  14    14  17    18     86       71.67
# 714   715    ZETA  12   1   6     7  15    12     53       44.17
# 715   716    ZETA  19  14  17    16  20    19    105       87.50
#
# [716 rows x 10 columns]

# %%
df.loc[df["Total"]>110,["Grade"]]="A+"
df.loc[(df["Total"]>90) & (df["Total"]<=110),["Grade"]]="A"
df.loc[(df["Total"]>70) & (df["Total"]<=90),["Grade"]]="B+"
df.loc[(df["Total"]>50) & (df["Total"]<=70),["Grade"]]="B"
df.loc[(df["Total"]<=50),["Grade"]]="Fail"
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
# [716 rows x 11 columns]

# %%
failed_students_Total = df[df["Total"] < 50]
print("DataFrame of students who failed in subjects:")
print(failed_students_Total)
# Out:
# DataFrame of students who failed in subjects:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 20     21   ALPHA   4   2   5     3  16     9     39       32.50  Fail
# 27     28   ALPHA   5   4   3    12  13     5     42       35.00  Fail
# 57     58   ALPHA   2   2   4    10  10     3     31       25.83  Fail
# 75     76   ALPHA   5   8   7    15  10     2     47       39.17  Fail
# 82     83   ALPHA   2   0   2    -1  -1    -1      1        0.83  Fail
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 667   668    ZETA  16   6  -1    -1   8     9     37       30.83  Fail
# 671   672    ZETA   2  -1   0     0   2     1      4        3.33  Fail
# 677   678    ZETA  11   0   8     4   1    11     35       29.17  Fail
# 683   684    ZETA   5   1   4    15   1     6     32       26.67  Fail
# 687   688    ZETA   6   3   4     9  10    15     47       39.17  Fail
#
# [88 rows x 11 columns]

# %%
df.sort_values(["Total"], ascending=True)
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 495   496   OMEGA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 556   557   SIGMA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 244   245   DELTA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 402   403   GAMMA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# 551   552   SIGMA  -1  -1  -1    -1  -1    -1     -6       -5.00  Fail
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 251   252   DELTA  20  20  20    19  20    20    119       99.17    A+
# 505   506   OMEGA  20  20  20    20  20    20    120      100.00    A+
# 573   574   SIGMA  20  20  20    20  20    20    120      100.00    A+
# 595   596   SIGMA  20  20  20    20  20    20    120      100.00    A+
# 507   508   OMEGA  20  20  20    20  20    20    120      100.00    A+
#
# [716 rows x 11 columns]

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="DV", y="Total", data=df, marker="o")
plt.xlabel("DV")
plt.ylabel("Total")
plt.title("Marks in DV comparing with Percentage")
plt.show()

# %% [markdown]
# student those who scored avg marks ,they also scored max total marks and student those
# who scored 0 in subject they have scored min marks

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="PP", y="Total", data=df, marker="o")
plt.xlabel("PP")
plt.ylabel("Total")
plt.title("Marks in PP comparing with Percentage")
plt.show()

# %% [markdown]
# Students who scored 0 in PP has scored 90 and student who scored 20 has scored
# maximum marks

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="FIMS", y="Total", data=df, marker="o")
plt.xlabel("FIMS")
plt.ylabel("Total")
plt.title("Marks in FIMS comparing with Percentage")
plt.show()

# %% [markdown]
# continuosly graph is increasing in FIMS and total score is also increasing

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="M2", y="Total", data=df, marker="o")
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %% [markdown]
# students those who got min marks they got min marks in total and who scored max marks
# got max marks in total

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="BEEE", y="Total", data=df, marker="o")
plt.xlabel("BEEE")
plt.ylabel("Total")
plt.title("Marks in BEEE comparing with Percentage")
plt.show()

# %% [markdown]
# continuosly graph is increasing in BEEE and total score is also increasing

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="FL", y="Total", data=df, marker="o")
plt.xlabel("FL")
plt.ylabel("Total")
plt.title("Marks in FL comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(x="M2", y="Total", data=df, marker="o")
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.barplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
df.loc[(df["PP"]>=18) & (df["PP"]<=20),["programming skills"]]="Very good"
df.loc[(df["PP"]>15) & (df["PP"]<=17),["programming skills"]]="good"
df.loc[(df["PP"]>12) & (df["Total"]<=14),["programming skills"]]="Avg"
df.loc[(df["PP"]<=12),["programming skills"]]="Fail"
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#     programming skills
# 0                 good
# 1                 good
# 2            Very good
# 3            Very good
# 4            Very good
# ..                 ...
# 711               Fail
# 712               Fail
# 713                NaN
# 714               Fail
# 715               good
#
# [716 rows x 12 columns]

# %%
category_counts = df["programming skills"].value_counts()
print("Category counts for 'PP':")
category_counts
# Out:
# Category counts for 'PP':
# Fail         326
# Very good    199
# good          83
# Name: programming skills, dtype: int64

# %%
df.loc[(df["DV"]>=18) & (df["DV"]<=20),["programming skills"]]="Very good"
df.loc[(df["DV"]>15) & (df["DV"]<=17),["programming skills"]]="good"
df.loc[(df["DV"]>12) & (df["Total"]<=14),["programming skills"]]="Avg"
df.loc[(df["DV"]<=12),["programming skills"]]="Fail"
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#     programming skills
# 0                 Fail
# 1            Very good
# 2            Very good
# 3            Very good
# 4            Very good
# ..                 ...
# 711          Very good
# 712               Fail
# 713               good
# 714               Fail
# 715          Very good
#
# [716 rows x 12 columns]

# %%
category_counts = df["programming skills"].value_counts()
print("Category counts for 'DV':")
category_counts
# Out:
# Category counts for 'DV':
# Fail         271
# Very good    255
# good         164
# Name: programming skills, dtype: int64

# %%
df["skilled"] = (df["PP"] == 20) | (df["DV"] == 20) | (df["M2"] == 20) | (df["BEEE"] == 20) | (df["FL"] == 20) | (df["FIMS"] == 20)
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#     programming skills  skilled
# 0                 Fail    False
# 1            Very good    False
# 2            Very good    False
# 3            Very good    False
# 4            Very good     True
# ..                 ...      ...
# 711          Very good    False
# 712               Fail     True
# 713               good    False
# 714               Fail    False
# 715          Very good     True
#
# [716 rows x 13 columns]

# %%
df.skilled.value_counts()
# Out:
# False    416
# True     300
# Name: skilled, dtype: int64

# %%
df.loc[(df["PP"]>=18) & (df["PP"]<=20),["Programming SKills"]]="Very Good"
df.loc[(df["PP"]>=15) & (df["PP"]<=17),["Programming SKills"]]="Good"
df.loc[(df["PP"]>=12) & (df["PP"]<=14),["Programming SKills"]]="Average"
df.loc[(df["PP"]<=11),["Programming SKills"]]="Poor"
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#     programming skills  skilled Programming SKills
# 0                 Fail    False               Good
# 1            Very good    False               Good
# 2            Very good    False          Very Good
# 3            Very good    False          Very Good
# 4            Very good     True          Very Good
# ..                 ...      ...                ...
# 711          Very good    False               Poor
# 712               Fail     True               Poor
# 713               good    False            Average
# 714               Fail    False               Poor
# 715          Very good     True               Good
#
# [716 rows x 14 columns]

# %%
df.loc[(df["DV"]>=18) & (df["DV"]<=20),["Analytical SKills"]]="Very Good"
df.loc[(df["DV"]>=15) & (df["DV"]<=17),["Analytical SKills"]]="Good"
df.loc[(df["DV"]>=12) & (df["DV"]<=14),["Analytical SKills"]]="Average"
df.loc[(df["DV"]<=11),["Analytical SKills"]]="Poor"
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#     programming skills  skilled Programming SKills Analytical SKills
# 0                 Fail    False               Good           Average
# 1            Very good    False               Good         Very Good
# 2            Very good    False          Very Good         Very Good
# 3            Very good    False          Very Good              Good
# 4            Very good     True          Very Good         Very Good
# ..                 ...      ...                ...               ...
# 711          Very good    False               Poor         Very Good
# 712               Fail     True               Poor           Average
# 713               good    False            Average              Good
# 714               Fail    False               Poor           Average
# 715          Very good     True               Good         Very Good
#
# [716 rows x 15 columns]

# %%
total_1=df["Programming SKills"].value_counts()
total_1.plot(kind='pie', figsize=(8, 8),autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of Total Students in each Section")
plt.show()

# %%
total1=df["Analytical SKills"].value_counts()
total1.plot(kind='pie', figsize=(8, 8),autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of Total Students in each Section")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   S.NO                716 non-null    int64
#  1   SECTION             716 non-null    object
#  2   DV                  716 non-null    int32
#  3   M2                  716 non-null    int32
#  4   PP                  716 non-null    int32
#  5   BEEE                716 non-null    int32
#  6   FL                  716 non-null    int32
#  7   FIMS                716 non-null    int32
#  8   Total               716 non-null    int32
#  9   Percentage          716 non-null    float64
#  10  Grade               716 non-null    object
#  11  programming skills  690 non-null    object
#  12  skilled             716 non-null    bool
#  13  Programming SKills  716 non-null    object
#  14  Analytical SKills   716 non-null    object
# dtypes: bool(1), float64(1), int32(7), int64(1), object(5)
# memory usage: 59.6+ KB

# %%
alpha_mean = df[df['Category']=='alpha']['value'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6384\4218316516.py in <module>
# ----> 1 alpha_mean = df[df['Category']=='alpha']['value'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Category'

# %%
df.section=alpha.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6384\345900702.py in <module>
# ----> 1 df.section=alpha.mean()
#
# NameError: name 'alpha' is not defined

# %%
df.SECTION=ALPHA.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6384\516535199.py in <module>
# ----> 1 df.SECTION=ALPHA.mean()
#
# NameError: name 'ALPHA' is not defined

# %%
df.SECTION=ALPHA.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6384\399402385.py in <module>
# ----> 1 df.SECTION=ALPHA.mean()
#
# NameError: name 'ALPHA' is not defined

# %%
df[df["SECTION"]=="ALPHA"].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\1973289253.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="ALPHA"].mean()
# S.NO          45.500000
# DV            13.411111
# M2            13.711111
# PP            15.922222
# BEEE          15.611111
# FL            16.166667
# FIMS          12.688889
# Total         87.511111
# Percentage    72.925556
# skilled        0.477778
# dtype: float64

# %%
df[df["SECTION"]=="BETA"].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\2603967371.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="BETA"].mean()
# S.NO          135.500000
# DV             13.000000
# M2             12.122222
# PP             15.955556
# BEEE           10.844444
# FL             15.977778
# FIMS           14.044444
# Total          81.944444
# Percentage     68.287111
# skilled         0.400000
# dtype: float64

# %%
df[df["SECTION"]=="DELTA"].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\2445143256.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="DELTA"].mean()
# S.NO          225.500000
# DV             13.833333
# M2              9.477778
# PP             12.411111
# BEEE            9.433333
# FL             14.544444
# FIMS           16.555556
# Total          76.255556
# Percentage     63.545778
# skilled         0.333333
# dtype: float64

# %%
df[df["SECTION"]=="EPSILON"].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\134439638.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="EPSILON"].mean()
# S.NO          314.500000
# DV             15.204545
# M2              6.681818
# PP              8.556818
# BEEE           14.420455
# FL             15.306818
# FIMS           12.056818
# Total          72.227273
# Percentage     60.188864
# skilled         0.318182
# dtype: float64

# %%
df[df["SECTION"]=="GAMMA"].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\210123041.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="GAMMA"].mean()
# S.NO          403.500000
# DV             14.777778
# M2              9.255556
# PP             10.733333
# BEEE           14.755556
# FL             15.611111
# FIMS           12.388889
# Total          77.522222
# Percentage     64.602111
# skilled         0.355556
# dtype: float64

# %%
df[df["SECTION"]=="OMEGA"].mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\1774092647.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="OMEGA"].mean()
# S.NO          493.500000
# DV             16.533333
# M2              8.244444
# PP             14.577778
# BEEE           13.455556
# FL             15.577778
# FIMS           15.022222
# Total          83.411111
# Percentage     69.509111
# skilled         0.533333
# dtype: float64

# %%
df.groupby(SECTION.mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6384\2488389926.py in <module>
# ----> 1 df.groupby(SECTION.mean)
#
# NameError: name 'SECTION' is not defined

# %%
df.rename(columns={'M-II':'M2'},inplace=True)
df['S.NO'] = range(1, len(df) + 1)
df
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#     programming skills  skilled Programming SKills Analytical SKills
# 0                 Fail    False               Good           Average
# 1            Very good    False               Good         Very Good
# 2            Very good    False          Very Good         Very Good
# 3            Very good    False          Very Good              Good
# 4            Very good     True          Very Good         Very Good
# ..                 ...      ...                ...               ...
# 711          Very good    False               Poor         Very Good
# 712               Fail     True               Poor           Average
# 713               good    False            Average              Good
# 714               Fail    False               Poor           Average
# 715          Very good     True               Good         Very Good
#
# [716 rows x 15 columns]

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\1412173193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['S.NO'] = range(1, len(df) + 1)
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 711   686    ZETA  19   8   8    19  17    18     89       74.17    B+
# 712   687    ZETA  12   1   7    10  20     8     58       48.33     B
# 713   688    ZETA  17   6  14    14  17    18     86       71.67    B+
# 714   689    ZETA  12   1   6     7  15    12     53       44.17     B
# 715   690    ZETA  19  14  17    16  20    19    105       87.50     A
#
#     programming skills  skilled Programming SKills Analytical SKills
# 0                 Fail    False               Good           Average
# 1            Very good    False               Good         Very Good
# 2            Very good    False          Very Good         Very Good
# 3            Very good    False          Very Good              Good
# 4            Very good     True          Very Good         Very Good
# ..                 ...      ...                ...               ...
# 711          Very good    False               Poor         Very Good
# 712               Fail     True               Poor           Average
# 713               good    False            Average              Good
# 714               Fail    False               Poor           Average
# 715          Very good     True               Good         Very Good
#
# [690 rows x 15 columns]

# %%
df=pd.read_excel("MIDMARKS.xlsx")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 711   NaN    ZETA  19    8   8   19  17   18
# 712   NaN    ZETA  12    1   7   10  20    8
# 713   NaN    ZETA  17    6  14   14  17   18
# 714   NaN    ZETA  12    1   6    7  15   12
# 715   NaN    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df.groupby(SECTION.mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6384\2488389926.py in <module>
# ----> 1 df.groupby(SECTION.mean)
#
# NameError: name 'SECTION' is not defined

# %%
df[df["SECTION"]=="ALPHA"].std()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6384\1588783667.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df["SECTION"]=="ALPHA"].std()
# S.NO    26.124701
# DV       4.991891
# M-II     5.595432
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     600 non-null    float64
#  1   SECTION  690 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 44.9+ KB
